# %%
import numpy as np
import pandas as pd
import matplotlib as mp

cars = pd.DataFrame(pd.read_csv("cars.csv"))

# %%
cars[:3]
# Out:
#   manufacturer_name model_name transmission   color  odometer_value  \
# 0            Subaru    Outback    automatic  silver          190000
# 1            Subaru    Outback    automatic    blue          290000
# 2            Subaru   Forester    automatic     red          402000
#
#    year_produced engine_fuel  engine_has_gas engine_type  engine_capacity  \
# 0           2012    gasoline           False    gasoline              2.5
# 1           2004    gasoline           False    gasoline              3.0
# 2           2003    gasoline           False    gasoline              2.5
#
#    body_type  has_warranty  state drivetrain  price_usd  is_exchangeable  \
# 0  universal         False  owned        all    15260.0            False
# 1  universal         False  owned        all     7000.0             True
# 2        suv         False  owned        all     3920.0             True
#
#    number_of_photos  up_counter  duration_listed
# 0               4.5         6.5              8.0
# 1               6.0        27.0             41.5
# 2               2.0        36.0             75.5

# %%
cars.shape
# Out:
# (38531, 19)

# %%
cars.describe()
# Out:
#        odometer_value  year_produced  engine_capacity     price_usd  \
# count    38531.000000   38531.000000     38521.000000  38531.000000
# mean    248864.638447    2004.943734         2.055161   9295.959430
# std     136072.376530       8.065731         0.671178   8999.412825
# min          0.000000    1944.000000         0.200000      1.400000
# 25%     158000.000000    2000.000000         1.600000   2940.000000
# 50%     250000.000000    2005.000000         2.000000   6720.000000
# 75%     325000.000000    2011.000000         2.300000  12586.000000
# max    1000000.000000    2021.000000         8.000000  70000.000000
#
#        number_of_photos    up_counter  duration_listed
# count      38531.000000  38531.000000     38531.000000
# mean           4.824531      8.153046        40.288625
# std            3.046608     21.643467        56.413284
# min            0.500000      0.500000         0.000000
# 25%            2.500000      1.000000        11.500000
# 50%            4.000000      2.500000        29.500000
# 75%            6.000000      8.000000        45.500000
# max           43.000000    930.500000      1116.000000

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38531 entries, 0 to 38530
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   manufacturer_name  38531 non-null  object
#  1   model_name         38531 non-null  object
#  2   transmission       38531 non-null  object
#  3   color              38531 non-null  object
#  4   odometer_value     38531 non-null  int64
#  5   year_produced      38531 non-null  int64
#  6   engine_fuel        38531 non-null  object
#  7   engine_has_gas     38531 non-null  bool
#  8   engine_type        38531 non-null  object
#  9   engine_capacity    38521 non-null  float64
#  10  body_type          38531 non-null  object
#  11  has_warranty       38531 non-null  bool
#  12  state              38531 non-null  object
#  13  drivetrain         38531 non-null  object
#  14  price_usd          38531 non-null  float64
#  15  is_exchangeable    38531 non-null  bool
#  16  number_of_photos   38531 non-null  float64
#  17  up_counter         38531 non-null  float64
#  18  duration_listed    38531 non-null  float64
# dtypes: bool(3), float64(5), int64(2), object(9)
# memory usage: 4.8+ MB

# %%
cars.isna().sum()
# Out:
# manufacturer_name     0
# model_name            0
# transmission          0
# color                 0
# odometer_value        0
# year_produced         0
# engine_fuel           0
# engine_has_gas        0
# engine_type           0
# engine_capacity      10
# body_type             0
# has_warranty          0
# state                 0
# drivetrain            0
# price_usd             0
# is_exchangeable       0
# number_of_photos      0
# up_counter            0
# duration_listed       0
# dtype: int64

# %%
cars["engine_capacity"].dropna()
# Out:
# 0        2.5
# 1        3.0
# 2        2.5
# 3        3.0
# 4        2.5
#         ...
# 38526    3.5
# 38527    2.2
# 38528    3.5
# 38529    2.0
# 38530    2.4
# Name: engine_capacity, Length: 38521, dtype: float64

# %%
cars["age"] = 2023 - cars["year_produced"]
cars
# Out:
#       manufacturer_name  model_name transmission   color  odometer_value  \
# 0                Subaru     Outback    automatic  silver          190000
# 1                Subaru     Outback    automatic    blue          290000
# 2                Subaru    Forester    automatic     red          402000
# 3                Subaru     Impreza   mechanical    blue           10000
# 4                Subaru      Legacy    automatic   black          280000
# ...                 ...         ...          ...     ...             ...
# 38526          Chrysler         300    automatic  silver          290000
# 38527          Chrysler  PT Cruiser   mechanical    blue          321000
# 38528          Chrysler         300    automatic    blue          777957
# 38529          Chrysler  PT Cruiser   mechanical   black           20000
# 38530          Chrysler     Voyager    automatic  silver          297729
#
#        year_produced engine_fuel  engine_has_gas engine_type  engine_capacity  \
# 0               2012    gasoline           False    gasoline              2.5
# 1               2004    gasoline           False    gasoline              3.0
# 2               2003    gasoline           False    gasoline              2.5
# 3               2001    gasoline           False    gasoline              3.0
# 4               2003    gasoline           False    gasoline              2.5
# ...              ...         ...             ...         ...              ...
# 38526           2002    gasoline           False    gasoline              3.5
# 38527           2006      diesel           False      diesel              2.2
# 38528           2002    gasoline           False    gasoline              3.5
# 38529           2003    gasoline           False    gasoline              2.0
# 38530           2002    gasoline           False    gasoline              2.4
#
#        body_type  has_warranty  state drivetrain  price_usd  is_exchangeable  \
# 0      universal         False  owned        all  15260.000            False
# 1      universal         False  owned        all   7000.000             True
# 2            suv         False  owned        all   3920.000             True
# 3          sedan         False  owned        all  13998.600             True
# 4      universal         False  owned        all   2987.754             True
# ...          ...           ...    ...        ...        ...              ...
# 38526      sedan         False  owned      front   3850.000             True
# 38527  hatchback         False  owned      front   6720.000             True
# 38528      sedan         False  owned      front   6020.000            False
# 38529    minivan         False  owned      front   5600.000             True
# 38530    minivan         False  owned      front   4480.000             True
#
#        number_of_photos  up_counter  duration_listed  age
# 0                   4.5         6.5              8.0   11
# 1                   6.0        27.0             41.5   19
# 2                   2.0        36.0             75.5   20
# 3                   4.5        21.0             43.0   22
# 4                   7.0         3.5              3.5   20
# ...                 ...         ...              ...  ...
# 38526               2.5        42.5            150.5   21
# 38527               2.0        10.0            158.5   17
# 38528               1.5        31.5            184.5   21
# 38529               3.5        78.0            245.0   20
# 38530               2.0        36.5            316.0   21
#
# [38531 rows x 20 columns]

# %%
cars_numeric = cars.select_dtypes(include=['float', 'int'])
cars_numeric.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38531 entries, 0 to 38530
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   odometer_value    38531 non-null  int64
#  1   year_produced     38531 non-null  int64
#  2   engine_capacity   38521 non-null  float64
#  3   price_usd         38531 non-null  float64
#  4   number_of_photos  38531 non-null  float64
#  5   up_counter        38531 non-null  float64
#  6   duration_listed   38531 non-null  float64
#  7   age               38531 non-null  int64
# dtypes: float64(5), int64(3)
# memory usage: 2.4 MB

# %%
cars.corr()
# Out:
#                   odometer_value  year_produced  engine_has_gas  \
# odometer_value          1.000000      -0.488679        0.057786
# year_produced          -0.488679       1.000000       -0.074686
# engine_has_gas          0.057786      -0.074686        1.000000
# engine_capacity         0.105704       0.005059        0.084579
# has_warranty           -0.189498       0.209231       -0.020667
# price_usd              -0.421204       0.705511       -0.062528
# is_exchangeable         0.042342      -0.057937        0.018646
# number_of_photos       -0.143708       0.258180       -0.032101
# up_counter             -0.020961       0.007945        0.000058
# duration_listed        -0.000428      -0.017001        0.018264
# age                     0.488679      -1.000000        0.074686
#
#                   engine_capacity  has_warranty  price_usd  is_exchangeable  \
# odometer_value           0.105704     -0.189498  -0.421204         0.042342
# year_produced            0.005059      0.209231   0.705511        -0.057937
# engine_has_gas           0.084579     -0.020667  -0.062528         0.018646
# engine_capacity          1.000000     -0.054583   0.296597         0.081636
# has_warranty            -0.054583      1.000000   0.285532         0.117775
# price_usd                0.296597      0.285532   1.000000        -0.000503
# is_exchangeable          0.081636      0.117775  -0.000503         1.000000
# number_of_photos         0.106691      0.084045   0.316859         0.103725
# up_counter               0.079152     -0.023087   0.057382         0.106213
# duration_listed          0.080081     -0.061798   0.033524         0.026897
# age                     -0.005059     -0.209231  -0.705511         0.057937
#
#                   number_of_photos  up_counter  duration_listed       age
# odometer_value           -0.143708   -0.020961        -0.000428  0.488679
# year_produced             0.258180    0.007945        -0.017001 -1.000000
# engine_has_gas           -0.032101    0.000058         0.018264  0.074686
# engine_capacity           0.106691    0.079152         0.080081 -0.005059
# has_warranty              0.084045   -0.023087        -0.061798 -0.209231
# price_usd                 0.316859    0.057382         0.033524 -0.705511
# is_exchangeable           0.103725    0.106213         0.026897  0.057937
# number_of_photos          1.000000    0.073891        -0.028255 -0.258180
# up_counter                0.073891    1.000000         0.698116 -0.007945
# duration_listed          -0.028255    0.698116         1.000000  0.017001
# age                      -0.258180   -0.007945         0.017001  1.000000

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
cars_numeric.hist(bins=50, figsize=(20,15))
plt.show()

# %%
y = cars_numeric["price_usd"]
cars_numeric.drop(columns="price_usd", inplace=True)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_cars_numeric_array = scaler.fit_transform(cars_numeric)
scaled_cars_numeric = pd.DataFrame(scaled_cars_numeric_array, index=cars_numeric.index, columns=cars_numeric.columns)
# Out:
#        odometer_value  year_produced  engine_capacity  number_of_photos  \
# 0           -0.432604       0.874857         0.662782         -0.106523
# 1            0.302309      -0.117007         1.407751          0.385834
# 2            1.125411      -0.240990         0.662782         -0.927119
# 3           -1.755446      -0.488956         1.407751         -0.106523
# 4            0.228818      -0.240990         0.662782          0.714072
# ...               ...            ...              ...               ...
# 38526        0.302309      -0.364973         2.152720         -0.763000
# 38527        0.530132       0.130959         0.215801         -0.927119
# 38528        3.888366      -0.364973         2.152720         -1.091238
# 38529       -1.681955      -0.240990        -0.082187         -0.434762
# 38530        0.359110      -0.364973         0.513789         -0.927119
#
#        up_counter  duration_listed       age
# 0       -0.076377        -0.572366 -0.874857
# 1        0.870803         0.021474  0.117007
# 2        1.286638         0.624176  0.240990
# 3        0.593580         0.048063  0.488956
# 4       -0.214989        -0.652135  0.240990
# ...           ...              ...       ...
# 38526    1.586964         1.953668  0.364973
# 38527    0.085337         2.095480 -0.130959
# 38528    1.078721         2.556370  0.364973
# 38529    3.227203         3.628827  0.240990
# 38530    1.309740         4.887412  0.364973
#
# [38531 rows x 7 columns]

# %%
cars[""].value_counts()
# Out:
# gasoline    25647
# diesel      12874
# electric       10
# Name: engine_type, dtype: int64

# %%
cars[["price_usd", "manufacturer_name"]].mean()
# Out:
# /var/folders/gw/_4bgp9b95959m06_4y4ykwhh0000gn/T/ipykernel_1237/3362644662.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   cars[["price_usd", "manufacturer_name"]].mean()
# price_usd    9295.95943
# dtype: float64
